# %%
#from __future__ import absolute_import
#from __future__ import division
#from __future__ import print_function
import os
import cv2
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

plt.ion()   # interactive mode 画图不阻止程序运行
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
classes = ['coat_length_labels','collar_design_labels', 'lapel_design_labels',
           'neck_design_labels','neckline_design_labels',
           'pant_length_labels', 'skirt_length_labels', 
           'sleeve_length_labels']    
####################################
#下面是把得到的结果中最大值变的更大
#####################################

df = pd.read_csv('../result/best/betterfai.csv', header=None)
df_load = df.copy()
df_load.columns = ['image_id', 'class','label']
df_load.reset_index(inplace=True, drop = True)


result = []
for i in tqdm(range(len(df_load))):
    
    #dfnp=df_load[(df_load.index == i)]
    
    if df_load['class'][i] == classes[0]:
        index = 0
        liststr = df_load['label'][i].split(";")
        maxint = 0
        for j, k in enumerate(liststr):
            if float(k) >= maxint:
                maxint = float(k)
                #print(maxint)
                index = j
        liststr[index] = '0.9999'
        tmp = ";".join(liststr)
        df_load['label'][i] = tmp
        #print(df_load['label'][i])

    
    if df_load['class'][i] == classes[1]:
        index = 0
        liststr = df_load['label'][i].split(";")
        maxint = 0
        for j, k in enumerate(liststr):
            if float(k) >= maxint:
                maxint = float(k)
                #print(maxint)
                index = j
        liststr[index] = '0.9998'
        tmp = ";".join(liststr)
        df_load['label'][i] = tmp
    
    if df_load['class'][i] == classes[2]:
        index = 0
        liststr = df_load['label'][i].split(";")
        maxint = 0
        for j, k in enumerate(liststr):
            if float(k) >= maxint:
                maxint = float(k)
                #print(maxint)
                index = j
        liststr[index] = '0.9999'
        tmp = ";".join(liststr)
        df_load['label'][i] = tmp
    
    if df_load['class'][i] == classes[3]:
        index = 0
        liststr = df_load['label'][i].split(";")
        maxint = 0
        for j, k in enumerate(liststr):
            if float(k) >= maxint:
                maxint = float(k)
                #print(maxint)
                index = j
        liststr[index] = '0.9999'
        tmp = ";".join(liststr)
        df_load['label'][i] = tmp
    
    if df_load['class'][i] == classes[4]:
        index = 0
        liststr = df_load['label'][i].split(";")
        maxint = 0
        for j, k in enumerate(liststr):
            if float(k) >= maxint:
                maxint = float(k)
                #print(maxint)
                index = j
        liststr[index] = '0.9999'
        tmp = ";".join(liststr)
        df_load['label'][i] = tmp
    
    if df_load['class'][i] == classes[5]:
        index = 0
        liststr = df_load['label'][i].split(";")
        maxint = 0
        for j, k in enumerate(liststr):
            if float(k) >= maxint:
                maxint = float(k)
                #print(maxint)
                index = j
        liststr[index] = '0.9999'
        tmp = ";".join(liststr)
        df_load['label'][i] = tmp
    
    if df_load['class'][i] == classes[6]:
        index = 0
        liststr = df_load['label'][i].split(";")
        maxint = 0
        for j, k in enumerate(liststr):
            if float(k) >= maxint:
                maxint = float(k)
                #print(maxint)
                index = j
        liststr[index] = '0.9999'
        tmp = ";".join(liststr)
        df_load['label'][i] = tmp
    
    if df_load['class'][i] == classes[7]:
        index = 0
        liststr = df_load['label'][i].split(";")
        maxint = 0
        for j, k in enumerate(liststr):
            if float(k) >= maxint:
                maxint = float(k)
                #print(maxint)
                index = j
        liststr[index] = '0.9998'
        tmp = ";".join(liststr)
        df_load['label'][i] = tmp
     
df_load.to_csv('../result/best/trick/result.csv', header=None, index=False)
# Out:
# 100%|██████████| 10080/10080 [00:05<00:00, 1918.20it/s]
